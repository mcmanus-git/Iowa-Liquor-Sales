# %%
from MyCreds.mycreds import IowaData
import pandas as pd
from sodapy import Socrata
import numpy as np
import h3

KEY = IowaData.api_key
SECRET = IowaData.api_key_secret
TOKEN = IowaData.app_token

# %% [markdown]
# # Iowa Liquor Sales

# %%
liquor_sales_data_id = "m3tr-qhgy"

# %%
#!/usr/bin/env python
# Reference: https://dev.socrata.com/foundry/data.iowa.gov/m3tr-qhgy

# make sure to install these packages before running:
# pip install sodapy


# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.iowa.gov", app_token=TOKEN)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get(liquor_sales_data_id, limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
#      invoice_line_no                     date store  \
# 0       S32237200017  2016-05-10T00:00:00.000  4533
# 1       S32326100005  2016-05-16T00:00:00.000  3612
# 2       S32350600161  2016-05-16T00:00:00.000  2633
# 3       S32246800175  2016-05-10T00:00:00.000  2666
# 4       S32349300041  2016-05-17T00:00:00.000  4209
# ...              ...                      ...   ...
# 1995    S32344500098  2016-05-16T00:00:00.000  4829
# 1996    S32303000001  2016-05-18T00:00:00.000  2513
# 1997    S32294500007  2016-05-12T00:00:00.000  5169
# 1998    S32342800026  2016-05-16T00:00:00.000  2627
# 1999    S32324600024  2016-05-16T00:00:00.000  4856
#
#                                       name                         address  \
# 0     Casey's General Store #1985 / St. An                   110 N Hwy 218
# 1               B and C Liquor / Maquoketa                     509 E Platt
# 2             Hy-Vee #3 / BDI / Des Moines                 3221 SE 14th St
# 3                       Hy-Vee #2 / Ankeny                2510 SW State St
# 4                   Wal-Mart 5748 / Grimes                2150 East 1st St
# ...                                    ...                             ...
# 1995                        Central City 2               1501 Michigan Ave
# 1996      Hy-Vee Food Store #2 / Iowa City                  812  S 1st Ave
# 1997                          AV Superstop            5120, NE 14th Street
# 1998            Hy-Vee Wine and Spirits #1  3424 Martin Luther King Jr Pkw
# 1999              Brothers Market / Lisbon               930 Commercial St
#
#             city zipcode                                     store_location  \
# 0      St Ansgar   50472  {'type': 'Point', 'coordinates': [-92.917588, ...
# 1      Maquoketa   52060  {'type': 'Point', 'coordinates': [-90.659692, ...
# 2     Des Moines   50320  {'type': 'Point', 'coordinates': [-93.596754, ...
# 3         Ankeny   50023  {'type': 'Point', 'coordinates': [-93.621824, ...
# 4         Grimes   50111  {'type': 'Point', 'coordinates': [-93.771698, ...
# ...          ...     ...                                                ...
# 1995  Des Moines   50314  {'type': 'Point', 'coordinates': [-93.613739, ...
# 1996   Iowa City   52240                                                NaN
# 1997  Des Moines   50313  {'type': 'Point', 'coordinates': [-93.60054000...
# 1998  Des Moines   50310  {'type': 'Point', 'coordinates': [-93.65129, 4...
# 1999      Lisbon   52253  {'type': 'Point', 'coordinates': [-91.401062, ...
#
#      county_number    county  ... state_bottle_retail sale_bottles  \
# 0               66  Mitchell  ...               15.74           24
# 1               49   Jackson  ...               27.00            6
# 2               77      Polk  ...               13.88           12
# 3               77      Polk  ...                9.00            1
# 4               77      Polk  ...                5.01           12
# ...            ...       ...  ...                 ...          ...
# 1995            77      Polk  ...               18.89            3
# 1996            52   Johnson  ...               19.47           10
# 1997            77      Polk  ...                8.61            4
# 1998            77      Polk  ...               17.25            3
# 1999            57      Linn  ...               12.99            4
#
#      sale_dollars sale_liters sale_gallons :@computed_region_3r5t_5243  \
# 0          377.76       18.00         4.76                         461
# 1          162.00       10.50         2.77                         153
# 2          166.56       12.00         3.17                         483
# 3            9.00        0.75         0.20                         831
# 4           60.12        9.00         2.38                         654
# ...           ...         ...          ...                         ...
# 1995        56.67        2.25         0.59                         432
# 1996       194.70        7.50         1.98                         NaN
# 1997        34.44        0.80         0.21                         829
# 1998        51.75        1.50         0.40                         684
# 1999        51.96        3.00         0.79                         467
#
#      :@computed_region_wnea_7qqw :@computed_region_i9mz_6gmt  \
# 0                             14                         171
# 1                              7                          80
# 2                             29                         356
# 3                             25                         316
# 4                             25                         315
# ...                          ...                         ...
# 1995                          25                         316
# 1996                         NaN                         NaN
# 1997                          25                         316
# 1998                          25                         316
# 1999                          19                         268
#
#      :@computed_region_uhgg_e8y2 :@computed_region_e7ym_nrbf
# 0                             10                         291
# 1                             43                        1790
# 2                             64                        1878
# 3                             64                        1878
# 4                             64                        1878
# ...                          ...                         ...
# 1995                          64                        1878
# 1996                         NaN                         NaN
# 1997                          64                        1878
# 1998                          64                        1878
# 1999                          45                         287
#
# [2000 rows x 29 columns]

# %% [markdown]
# # MetaData
#
# Gathering matadata for data descriptions and data types.

# %%
metadata = client.get_metadata(liquor_sales_data_id)
metadata
# Out:
# {'id': 'm3tr-qhgy',
#  'name': 'Iowa Liquor Sales',
#  'assetType': 'dataset',
#  'attribution': 'Iowa Department of Commerce, Alcoholic Beverages Division',
#  'averageRating': 0,
#  'category': 'Sales & Distribution',
#  'createdAt': 1415384381,
#  'description': 'This dataset contains the spirits purchase information of Iowa Class “E” liquor licensees by product and date of purchase from January 1, 2012 to current.  The dataset can be used to analyze total spirits sales in Iowa of individual products at the store level.\r\n\r\nClass E liquor license, for grocery stores, liquor stores, convenience stores, etc., allows commercial establishments to sell liquor for off-premises consumption in original unopened containers.',
#  'displayType': 'table',
#  'domainCName': 'data.iowa.gov',
#  'downloadCount': 11191,
#  'hideFromCatalog': False,
#  'hideFromDataJson': False,
#  'indexUpdatedAt': 1564675701,
#  'licenseId': 'CC0_10',
#  'newBackend': True,
#  'numberOfComments': 8,
#  'oid': 32061986,
#  'provenance': 'official',
#  'publicationAppendEnabled': False,
#  'publicationDate': 1564721008,
#  'publicationGroup': 1864764,
#  'publicationStage': 'published',
#  'rowClass': '',
#  'rowIdentifierColumnId': 421004091,
#  'rowsUpdatedAt': 1659650517,
#  'rowsUpdatedBy': '685n-hc2b',
#  'tableId': 16403480,
#  'totalTimesRated': 0,
#  'viewCount': 73447,
#  'viewLastModified': 1659650492,
#  'viewType': 'tabular',
#  'approvals': [{'reviewedAt': 1451506389,
#    'reviewedAutomatically': True,
#    'state': 'approved',
#    'submissionId': 1020570,
#    'submissionObject': 'public_audience_request',
#    'submissionOutcome': 'change_audience',
#    'submittedAt': 1451506389,
#    'workflowId': 1962,
#    'submissionDetails': {'permissionType': 'READ'},
#    'submissionOutcomeApplication': {'failureCount': 0, 'status': 'success'},
#    'submitter': {'id': 'mabe-sef7',
#     'displayName': 'Alcoholic Beverages Division (Commerce)'}}],
#  'clientContext': {'clientContextVariables': [], 'inheritedVariables': {}},
#  'columns': [{'id': 421004091,
#    'name': 'Invoice/Item Number',
#    'dataTypeName': 'text',
#    'description': 'Concatenated invoice and line number associated with the liquor order.  This provides a unique identifier for the individual liquor products included in the store order',
#    'fieldName': 'invoice_line_no',
#    'position': 1,
#    'renderTypeName': 'text',
#    'tableColumnId': 33137142,
#    'width': 127,
#    'cachedContents': {'largest': 'S444400083',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': '306831300002', 'count': '1'},
#      {'item': '306831300003', 'count': '1'},
#      {'item': '306831300004', 'count': '1'},
#      {'item': '306831300005', 'count': '1'},
#      {'item': '306831300006', 'count': '1'},
#      {'item': '306831300007', 'count': '1'},
#      {'item': '306831300008', 'count': '1'},
#      {'item': '306831300009', 'count': '1'},
#      {'item': '306831300010', 'count': '1'},
#      {'item': '306831300011', 'count': '1'},
#      {'item': '306831300012', 'count': '1'},
#      {'item': '306831300013', 'count': '1'},
#      {'item': '306831300014', 'count': '1'},
#      {'item': '306831300015', 'count': '1'},
#      {'item': '306831300016', 'count': '1'},
#      {'item': '306831300017', 'count': '1'},
#      {'item': '306831300018', 'count': '1'},
#      {'item': '306831300019', 'count': '1'},
#      {'item': '306831300020', 'count': '1'},
#      {'item': '306831300021', 'count': '1'}],
#     'not_null': '17300913',
#     'smallest': '306831300001',
#     'count': '24396811',
#     'cardinality': '24396811'},
#    'format': {'align': 'left'}},
#   {'id': 421004092,
#    'name': 'Date',
#    'dataTypeName': 'calendar_date',
#    'description': 'Date of order',
#    'fieldName': 'date',
#    'position': 2,
#    'renderTypeName': 'calendar_date',
#    'tableColumnId': 22767599,
#    'width': 100,
#    'cachedContents': {'largest': '2022-07-29T00:00:00.000',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': '2020-12-22T00:00:00.000', 'count': '18002'},
#      {'item': '2020-12-29T00:00:00.000', 'count': '17722'},
#      {'item': '2017-12-22T00:00:00.000', 'count': '16674'},
#      {'item': '2020-05-29T00:00:00.000', 'count': '16650'},
#      {'item': '2019-07-05T00:00:00.000', 'count': '16173'},
#      {'item': '2014-12-29T00:00:00.000', 'count': '15996'},
#      {'item': '2015-12-01T00:00:00.000', 'count': '15588'},
#      {'item': '2018-12-21T00:00:00.000', 'count': '15578'},
#      {'item': '2019-12-20T00:00:00.000', 'count': '15248'},
#      {'item': '2016-06-28T00:00:00.000', 'count': '15107'},
#      {'item': '2014-12-17T00:00:00.000', 'count': '14963'},
#      {'item': '2013-06-25T00:00:00.000', 'count': '14885'},
#      {'item': '2013-12-18T00:00:00.000', 'count': '14871'},
#      {'item': '2015-11-30T00:00:00.000', 'count': '14686'},
#      {'item': '2015-12-28T00:00:00.000', 'count': '14603'},
#      {'item': '2014-12-03T00:00:00.000', 'count': '14585'},
#      {'item': '2018-05-16T00:00:00.000', 'count': '14531'},
#      {'item': '2019-09-05T00:00:00.000', 'count': '14481'},
#      {'item': '2019-05-31T00:00:00.000', 'count': '14444'},
#      {'item': '2012-12-18T00:00:00.000', 'count': '14442'}],
#     'not_null': '17300913',
#     'smallest': '2012-01-03T00:00:00.000',
#     'count': '24396811',
#     'cardinality': '2680'},
#    'format': {'view': 'date', 'align': 'left'}},
#   {'id': 421004093,
#    'name': 'Store Number',
#    'dataTypeName': 'text',
#    'description': 'Unique number assigned to the store who ordered the liquor.',
#    'fieldName': 'store',
#    'position': 3,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767638,
#    'width': 100,
#    'cachedContents': {'largest': '9946',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': '2633', 'count': '202513'},
#      {'item': '4829', 'count': '170370'},
#      {'item': '2190', 'count': '160914'},
#      {'item': '2512', 'count': '137439'},
#      {'item': '2572', 'count': '128647'},
#      {'item': '2603', 'count': '126565'},
#      {'item': '2515', 'count': '123033'},
#      {'item': '2614', 'count': '122860'},
#      {'item': '2648', 'count': '117933'},
#      {'item': '2647', 'count': '117899'},
#      {'item': '2501', 'count': '113137'},
#      {'item': '2500', 'count': '109111'},
#      {'item': '2629', 'count': '108364'},
#      {'item': '2616', 'count': '107924'},
#      {'item': '2590', 'count': '106817'},
#      {'item': '2565', 'count': '106023'},
#      {'item': '3773', 'count': '105556'},
#      {'item': '4129', 'count': '105373'},
#      {'item': '2619', 'count': '105289'},
#      {'item': '2506', 'count': '104254'}],
#     'not_null': '17300913',
#     'smallest': '010016',
#     'count': '24396811',
#     'cardinality': '2780'},
#    'format': {'align': 'left'}},
#   {'id': 421004094,
#    'name': 'Store Name',
#    'dataTypeName': 'text',
#    'description': 'Name of store who ordered the liquor.',
#    'fieldName': 'name',
#    'position': 4,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767676,
#    'width': 161,
#    'cachedContents': {'largest': "Z's Quickbreak",
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': 'Hy-Vee #3 / BDI / Des Moines', 'count': '202513'},
#      {'item': 'Central City 2', 'count': '170406'},
#      {'item': 'Central City Liquor, Inc.', 'count': '160878'},
#      {'item': 'Hy-Vee Wine and Spirits / Iowa City', 'count': '137439'},
#      {'item': 'Hy-Vee Food Store / Cedar Falls', 'count': '128647'},
#      {'item': 'Hy-Vee Wine and Spirits / Bettendorf', 'count': '126565'},
#      {'item': 'Hy-Vee Food Store #1 / Mason City', 'count': '123033'},
#      {'item': 'Hy-Vee #7 / Cedar Rapids', 'count': '116924'},
#      {'item': 'Hy-Vee Food Store #1 / Ames', 'count': '109111'},
#      {'item': 'Hy-Vee Food and Drug / Clinton', 'count': '107924'},
#      {'item': 'Hy-Vee Food Store #5 / Cedar Rapids', 'count': '106836'},
#      {'item': 'Benz Distributing', 'count': '105592'},
#      {'item': 'Cyclone Liquors', 'count': '105373'},
#      {'item': 'Hy-Vee Wine and Spirits / WDM', 'count': '105289'},
#      {'item': 'Hy-Vee #1044 / Burlington', 'count': '104254'},
#      {'item': 'Hy-Vee #4 / WDM', 'count': '101435'},
#      {'item': 'Hy-Vee Food Store / Muscatine', 'count': '99094'},
#      {'item': 'Hy-Vee Food Store #3 / Cedar Rapids', 'count': '97010'},
#      {'item': 'Hy-Vee Food Store / Coralville', 'count': '94631'},
#      {'item': 'Hy-Vee Food Store / Fleur / DSM', 'count': '93685'}],
#     'not_null': '17300913',
#     'smallest': '10th Hole Inn & Suite / Gift Shop',
#     'count': '24396811',
#     'cardinality': '2943'},
#    'format': {'align': 'left'}},
#   {'id': 421004095,
#    'name': 'Address',
#    'dataTypeName': 'text',
#    'description': 'Address of store who ordered the liquor.',
#    'fieldName': 'address',
#    'position': 5,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767693,
#    'width': 219,
#    'cachedContents': {'largest': 'PO BOX 261  310 W DILLON',
#     'non_null': '24316118',
#     'null': '80693',
#     'top': [{'item': '3221 SE 14th St', 'count': '164994'},
#      {'item': '1460 2ND AVE', 'count': '159857'},
#      {'item': '3221 SE 14TH ST', 'count': '110543'},
#      {'item': '1501 Michigan Ave', 'count': '108172'},
#      {'item': '6301 University', 'count': '93771'},
#      {'item': '507 W 19th St', 'count': '82356'},
#      {'item': '2890 Devils Glen Road', 'count': '80626'},
#      {'item': '2004 8th  St', 'count': '78221'},
#      {'item': '5050 Edgewood Rd', 'count': '74168'},
#      {'item': '555 S 51st St', 'count': '72856'},
#      {'item': '2400 4th St SW', 'count': '72173'},
#      {'item': '1720 Waterfront Dr', 'count': '71134'},
#      {'item': '2510 SW State St', 'count': '69827'},
#      {'item': '626 Lincoln Way', 'count': '69041'},
#      {'item': '501 7th Ave SE', 'count': '68967'},
#      {'item': '5925 University Ave', 'count': '68238'},
#      {'item': '2411 S 24TH ST #1', 'count': '67247'},
#      {'item': '1823 E Kimberly Rd', 'count': '66387'},
#      {'item': '1720 WATERFRONT DR', 'count': '66305'},
#      {'item': '1725  74th St', 'count': '66084'}],
#     'not_null': '17221572',
#     'smallest': '1000 N Jefferson St',
#     'count': '24396811',
#     'cardinality': '4108'},
#    'format': {'align': 'left'}},
#   {'id': 421004096,
#    'name': 'City',
#    'dataTypeName': 'text',
#    'description': 'City where the store who ordered the liquor is located',
#    'fieldName': 'city',
#    'position': 6,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767699,
#    'width': 100,
#    'cachedContents': {'largest': 'ZWINGLE',
#     'non_null': '24316119',
#     'null': '80692',
#     'top': [{'item': 'Des Moines', 'count': '1286686'},
#      {'item': 'Cedar Rapids', 'count': '980712'},
#      {'item': 'DES MOINES', 'count': '811086'},
#      {'item': 'Davenport', 'count': '637087'},
#      {'item': 'CEDAR RAPIDS', 'count': '597416'},
#      {'item': 'Waterloo', 'count': '478070'},
#      {'item': 'Sioux City', 'count': '455523'},
#      {'item': 'West Des Moines', 'count': '451709'},
#      {'item': 'Council Bluffs', 'count': '447583'},
#      {'item': 'DAVENPORT', 'count': '411104'},
#      {'item': 'Ames', 'count': '402473'},
#      {'item': 'Iowa City', 'count': '397940'},
#      {'item': 'Dubuque', 'count': '389422'},
#      {'item': 'Cedar Falls', 'count': '329113'},
#      {'item': 'Ankeny', 'count': '312036'},
#      {'item': 'WATERLOO', 'count': '289538'},
#      {'item': 'IOWA CITY', 'count': '286109'},
#      {'item': 'COUNCIL BLUFFS', 'count': '265827'},
#      {'item': 'SIOUX CITY', 'count': '248627'},
#      {'item': 'AMES', 'count': '247979'}],
#     'not_null': '17221573',
#     'smallest': 'Ackley',
#     'count': '24396811',
#     'cardinality': '859'},
#    'format': {'align': 'left'}},
#   {'id': 421004097,
#    'name': 'Zip Code',
#    'dataTypeName': 'text',
#    'description': 'Zip code where the store who ordered the liquor is located',
#    'fieldName': 'zipcode',
#    'position': 7,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767784,
#    'width': 100,
#    'cachedContents': {'largest': '80904',
#     'non_null': '24316074',
#     'null': '80737',
#     'top': [{'item': '50010', 'count': '589667'},
#      {'item': '52402', 'count': '563104'},
#      {'item': '52240', 'count': '527943'},
#      {'item': '50613', 'count': '466288'},
#      {'item': '50317', 'count': '432454'},
#      {'item': '51501', 'count': '429316'},
#      {'item': '52001', 'count': '404624'},
#      {'item': '50265', 'count': '399752'},
#      {'item': '50314', 'count': '396613'},
#      {'item': '52404', 'count': '381968'},
#      {'item': '52241', 'count': '360961'},
#      {'item': '50401', 'count': '344395'},
#      {'item': '52807', 'count': '324537'},
#      {'item': '52722', 'count': '303224'},
#      {'item': '52761', 'count': '299616'},
#      {'item': '50702', 'count': '298670'},
#      {'item': '50266', 'count': '296197'},
#      {'item': '52804', 'count': '295756'},
#      {'item': '51503', 'count': '281328'},
#      {'item': '50322', 'count': '280983'}],
#     'not_null': '17221528',
#     'smallest': '50002',
#     'count': '24396811',
#     'cardinality': '509'},
#    'format': {'align': 'left'}},
#   {'id': 421004098,
#    'name': 'Store Location',
#    'dataTypeName': 'point',
#    'description': 'Location of store who ordered the liquor.  The Address, City, State and Zip Code are geocoded to provide geographic coordinates.  Accuracy of geocoding is dependent on how well the address is interpreted and the completeness of the reference data used.',
#    'fieldName': 'store_location',
#    'position': 8,
#    'renderTypeName': 'point',
#    'tableColumnId': 22767821,
#    'width': 100,
#    'cachedContents': {'non_null': '21990818',
#     'null': '2405993',
#     'top': [{'item': {'coordinates': [-93.596754, 41.554101], 'type': 'Point'},
#       'count': '189532'},
#      {'item': {'coordinates': [-93.613739, 41.60572], 'type': 'Point'},
#       'count': '155441'},
#      {'item': {'coordinates': [-93.619787, 41.60566], 'type': 'Point'},
#       'count': '151647'},
#      {'item': {'coordinates': [-91.53046300000001, 41.642764],
#        'type': 'Point'},
#       'count': '131200'},
#      {'item': {'coordinates': [-92.435236, 42.512789], 'type': 'Point'},
#       'count': '128643'},
#      {'item': {'coordinates': [-90.548919, 41.55678100000001],
#        'type': 'Point'},
#       'count': '117924'},
#      {'item': {'coordinates': [-90.483701, 41.552338], 'type': 'Point'},
#       'count': '117892'},
#      {'item': {'coordinates': [-91.701581, 42.030129], 'type': 'Point'},
#       'count': '115842'},
#      {'item': {'coordinates': [-93.773557, 41.561197], 'type': 'Point'},
#       'count': '109428'},
#      {'item': {'coordinates': [-95.14506, 43.145897], 'type': 'Point'},
#       'count': '106023'},
#      {'item': {'coordinates': [-91.659875, 41.97574], 'type': 'Point'},
#       'count': '105554'},
#      {'item': {'coordinates': [-93.808855, 41.598515], 'type': 'Point'},
#       'count': '105285'},
#      {'item': {'coordinates': [-91.136655, 40.814666], 'type': 'Point'},
#       'count': '104252'},
#      {'item': {'coordinates': [-90.193204, 41.836268000000004],
#        'type': 'Point'},
#       'count': '102067'},
#      {'item': {'coordinates': [-95.825137, 41.242732], 'type': 'Point'},
#       'count': '101060'},
#      {'item': {'coordinates': [-91.658105, 42.010971], 'type': 'Point'},
#       'count': '99990'},
#      {'item': {'coordinates': [-93.618911, 42.022854], 'type': 'Point'},
#       'count': '99206'},
#      {'item': {'coordinates': [-92.429331, 42.512766], 'type': 'Point'},
#       'count': '96441'},
#      {'item': {'coordinates': [-93.619455, 42.022848], 'type': 'Point'},
#       'count': '95784'},
#      {'item': {'coordinates': [-91.035138, 41.451349], 'type': 'Point'},
#       'count': '92585'}],
#     'not_null': '15624172',
#     'count': '24396811',
#     'cardinality': '3188'},
#    'format': {'view': 'coords', 'align': 'left'}},
#   {'id': 421004099,
#    'name': 'County Number',
#    'dataTypeName': 'text',
#    'description': 'Iowa county number for the county where store who ordered the liquor is located\n',
#    'fieldName': 'county_number',
#    'position': 9,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767822,
#    'width': 113,
#    'cachedContents': {'largest': '99',
#     'non_null': '24139924',
#     'null': '256887',
#     'top': [{'item': '77', 'count': '4461709'},
#      {'item': '57', 'count': '2014013'},
#      {'item': '82', 'count': '1472463'},
#      {'item': '52', 'count': '1210675'},
#      {'item': '7', 'count': '826414'},
#      {'item': '78', 'count': '796545'},
#      {'item': '85', 'count': '772023'},
#      {'item': '97', 'count': '755430'},
#      {'item': '31', 'count': '701551'},
#      {'item': '17', 'count': '534170'},
#      {'item': '07', 'count': '527424'},
#      {'item': '29', 'count': '362658'},
#      {'item': '70', 'count': '356572'},
#      {'item': '23', 'count': '331226'},
#      {'item': '30', 'count': '308463'},
#      {'item': '56', 'count': '283929'},
#      {'item': '25', 'count': '279476'},
#      {'item': '90', 'count': '278260'},
#      {'item': '64', 'count': '277162'},
#      {'item': '94', 'count': '274118'}],
#     'not_null': '17144768',
#     'smallest': '01',
#     'count': '24396811',
#     'cardinality': '108'},
#    'format': {'align': 'left'}},
#   {'id': 421004100,
#    'name': 'County',
#    'dataTypeName': 'text',
#    'description': 'County where the store who ordered the liquor is located\n',
#    'fieldName': 'county',
#    'position': 10,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767827,
#    'width': 100,
#    'cachedContents': {'largest': 'WRIGHT',
#     'non_null': '24239316',
#     'null': '157495',
#     'top': [{'item': 'POLK', 'count': '2467624'},
#      {'item': 'Polk', 'count': '2013709'},
#      {'item': 'LINN', 'count': '1178852'},
#      {'item': 'SCOTT', 'count': '853445'},
#      {'item': 'Linn', 'count': '843354'},
#      {'item': 'BLACK HAWK', 'count': '806528'},
#      {'item': 'JOHNSON', 'count': '724698'},
#      {'item': 'Scott', 'count': '624363'},
#      {'item': 'Black Hawk', 'count': '552997'},
#      {'item': 'Johnson', 'count': '490358'},
#      {'item': 'POTTAWATTA', 'count': '471896'},
#      {'item': 'WOODBURY', 'count': '470082'},
#      {'item': 'STORY', 'count': '454321'},
#      {'item': 'DUBUQUE', 'count': '417359'},
#      {'item': 'Pottawattamie', 'count': '325374'},
#      {'item': 'Story', 'count': '320334'},
#      {'item': 'Woodbury', 'count': '288241'},
#      {'item': 'Dubuque', 'count': '286739'},
#      {'item': 'CERRO GORD', 'count': '257954'},
#      {'item': 'Cerro Gordo', 'count': '228579'}],
#     'not_null': '17144770',
#     'smallest': 'Adair',
#     'count': '24396811',
#     'cardinality': '201'},
#    'format': {'align': 'left'}},
#   {'id': 421004101,
#    'name': 'Category',
#    'dataTypeName': 'text',
#    'description': 'Category code associated with the liquor ordered',
#    'fieldName': 'category',
#    'position': 11,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767828,
#    'width': 100,
#    'cachedContents': {'largest': '1901200',
#     'non_null': '24379837',
#     'null': '16974',
#     'top': [{'item': '1012100', 'count': '2338025'},
#      {'item': '1031100', 'count': '2266756'},
#      {'item': '1011200', 'count': '1505272'},
#      {'item': '1031080', 'count': '1265974'},
#      {'item': '1031200', 'count': '1214278'},
#      {'item': '1081600', 'count': '1068591'},
#      {'item': '1011100', 'count': '1054092'},
#      {'item': '1022100', 'count': '748149'},
#      {'item': '1062200', 'count': '731355'},
#      {'item': '1071100', 'count': '701774'},
#      {'item': '1062400', 'count': '685550'},
#      {'item': '1032200', 'count': '533278'},
#      {'item': '1041100', 'count': '531509'},
#      {'item': '1062310', 'count': '530323'},
#      {'item': '1081200', 'count': '530312'},
#      {'item': '1081400', 'count': '519429'},
#      {'item': '1051100', 'count': '482195'},
#      {'item': '1032100', 'count': '476015'},
#      {'item': '1081300', 'count': '464645'},
#      {'item': '1022200', 'count': '435082'}],
#     'not_null': '17285206',
#     'smallest': '1011000',
#     'count': '24396811',
#     'cardinality': '114'},
#    'format': {'align': 'left'}},
#   {'id': 421004102,
#    'name': 'Category Name',
#    'dataTypeName': 'text',
#    'description': 'Category of the liquor ordered.',
#    'fieldName': 'category_name',
#    'position': 12,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767829,
#    'width': 185,
#    'cachedContents': {'largest': 'White Rum',
#     'non_null': '24371771',
#     'null': '25040',
#     'top': [{'item': 'American Vodkas', 'count': '2167632'},
#      {'item': 'Canadian Whiskies', 'count': '1401813'},
#      {'item': 'VODKA 80 PROOF', 'count': '1265974'},
#      {'item': 'Straight Bourbon Whiskies', 'count': '961588'},
#      {'item': 'CANADIAN WHISKIES', 'count': '936212'},
#      {'item': 'Whiskey Liqueur', 'count': '734019'},
#      {'item': 'American Flavored Vodka', 'count': '711465'},
#      {'item': 'Spiced Rum', 'count': '685167'},
#      {'item': 'Blended Whiskies', 'count': '612482'},
#      {'item': 'STRAIGHT BOURBON WHISKIES', 'count': '543684'},
#      {'item': 'SPICED RUM', 'count': '530323'},
#      {'item': 'VODKA FLAVORED', 'count': '502813'},
#      {'item': 'Imported Vodkas', 'count': '474769'},
#      {'item': 'American Schnapps', 'count': '470820'},
#      {'item': 'American Brandies', 'count': '443686'},
#      {'item': 'BLENDED WHISKIES', 'count': '441610'},
#      {'item': 'TEQUILA', 'count': '435298'},
#      {'item': '100% Agave Tequila', 'count': '432512'},
#      {'item': 'Cocktails /RTD', 'count': '417079'},
#      {'item': 'IMPORTED VODKA', 'count': '404048'}],
#     'not_null': '17277140',
#     'smallest': '100% Agave Tequila',
#     'count': '24396811',
#     'cardinality': '136'},
#    'format': {'align': 'left'}},
#   {'id': 421004103,
#    'name': 'Vendor Number',
#    'dataTypeName': 'text',
#    'description': 'The vendor number of the company for the brand of liquor ordered',
#    'fieldName': 'vendor_no',
#    'position': 13,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767844,
#    'width': 100,
#    'cachedContents': {'largest': '987',
#     'non_null': '24396802',
#     'null': '9',
#     'top': [{'item': '260', 'count': '4057288'},
#      {'item': '434', 'count': '2178350'},
#      {'item': '421', 'count': '1844570'},
#      {'item': '370', 'count': '1452965'},
#      {'item': '065', 'count': '1290920'},
#      {'item': '259', 'count': '1244466'},
#      {'item': '115', 'count': '1041372'},
#      {'item': '65', 'count': '981089'},
#      {'item': '395', 'count': '941728'},
#      {'item': '380', 'count': '785858'},
#      {'item': '205', 'count': '760799'},
#      {'item': '297', 'count': '681734'},
#      {'item': '035', 'count': '598371'},
#      {'item': '055', 'count': '559866'},
#      {'item': '300', 'count': '537195'},
#      {'item': '085', 'count': '490985'},
#      {'item': '35', 'count': '489599'},
#      {'item': '55', 'count': '480349'},
#      {'item': '85', 'count': '445369'},
#      {'item': '301', 'count': '345195'}],
#     'not_null': '17300909',
#     'smallest': '010',
#     'count': '24396811',
#     'cardinality': '433'},
#    'format': {'align': 'left'}},
#   {'id': 421004104,
#    'name': 'Vendor Name',
#    'dataTypeName': 'text',
#    'description': 'The vendor name of the company for the brand of liquor ordered',
#    'fieldName': 'vendor_name',
#    'position': 14,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767847,
#    'width': 227,
#    'cachedContents': {'largest': 'YAHARA BAY DISTILLERS INC',
#     'non_null': '24396804',
#     'null': '7',
#     'top': [{'item': 'DIAGEO AMERICAS', 'count': '2372845'},
#      {'item': 'Jim Beam Brands', 'count': '2272009'},
#      {'item': 'Diageo Americas', 'count': '1684443'},
#      {'item': 'SAZERAC COMPANY  INC', 'count': '1386402'},
#      {'item': 'Heaven Hill Brands', 'count': '1244466'},
#      {'item': 'LUXCO INC', 'count': '1133816'},
#      {'item': 'Luxco-St Louis', 'count': '1044534'},
#      {'item': 'PERNOD RICARD USA', 'count': '824992'},
#      {'item': 'Pernod Ricard USA/Austin Nichols', 'count': '627973'},
#      {'item': 'BACARDI USA INC', 'count': '598371'},
#      {'item': 'PROXIMO', 'count': '585940'},
#      {'item': 'SAZERAC NORTH AMERICA', 'count': '559866'},
#      {'item': 'Constellation Wine Company, Inc.', 'count': '538552'},
#      {'item': 'E & J Gallo Winery', 'count': '509600'},
#      {'item': 'CONSTELLATION BRANDS INC', 'count': '502820'},
#      {'item': 'Brown Forman Corp.', 'count': '490985'},
#      {'item': 'Bacardi U.S.A., Inc.', 'count': '489599'},
#      {'item': 'Sazerac North America', 'count': '480349'},
#      {'item': 'Sazerac Co., Inc.', 'count': '458168'},
#      {'item': 'Brown-Forman Corporation', 'count': '445369'}],
#     'not_null': '17300911',
#     'smallest': '10th Mountain Whiskey & Spirit Company',
#     'count': '24396811',
#     'cardinality': '578'},
#    'format': {'align': 'left'}},
#   {'id': 421004105,
#    'name': 'Item Number',
#    'dataTypeName': 'text',
#    'description': 'Item number for the individual liquor product ordered.',
#    'fieldName': 'itemno',
#    'position': 15,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767859,
#    'width': 100,
#    'cachedContents': {'largest': 'x904631',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': '11788', 'count': '244346'},
#      {'item': '36308', 'count': '230454'},
#      {'item': '35918', 'count': '160173'},
#      {'item': '64858', 'count': '147487'},
#      {'item': '11776', 'count': '132984'},
#      {'item': '36904', 'count': '130558'},
#      {'item': '43336', 'count': '124272'},
#      {'item': '38176', 'count': '120210'},
#      {'item': '64866', 'count': '116911'},
#      {'item': '11774', 'count': '114476'},
#      {'item': '36306', 'count': '113282'},
#      {'item': '43028', 'count': '110526'},
#      {'item': '25608', 'count': '110065'},
#      {'item': '43337', 'count': '103884'},
#      {'item': '26826', 'count': '103228'},
#      {'item': '11296', 'count': '102710'},
#      {'item': '37996', 'count': '97909'},
#      {'item': '34006', 'count': '95174'},
#      {'item': '36908', 'count': '93642'},
#      {'item': '43338', 'count': '92201'}],
#     'not_null': '17300913',
#     'smallest': '100001',
#     'count': '24396811',
#     'cardinality': '11481'},
#    'format': {'align': 'left'}},
#   {'id': 421004106,
#    'name': 'Item Description',
#    'dataTypeName': 'text',
#    'description': 'Description of the individual liquor product ordered.',
#    'fieldName': 'im_desc',
#    'position': 16,
#    'renderTypeName': 'text',
#    'tableColumnId': 22767860,
#    'width': 308,
#    'cachedContents': {'largest': 'Zyr Vodka',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': 'Black Velvet', 'count': '620879'},
#      {'item': 'Hawkeye Vodka', 'count': '539589'},
#      {'item': 'Fireball Cinnamon Whiskey', 'count': '334350'},
#      {'item': 'Titos Handmade Vodka', 'count': '295820'},
#      {'item': "Five O'clock Vodka", 'count': '257290'},
#      {'item': 'Jim Beam', 'count': '255767'},
#      {'item': 'Captain Morgan Spiced Rum', 'count': '211468'},
#      {'item': 'Admiral Nelson Spiced Rum', 'count': '210524'},
#      {'item': 'Jagermeister Liqueur', 'count': '205352'},
#      {'item': 'Captain Morgan Original Spiced', 'count': '199692'},
#      {'item': 'Crown Royal', 'count': '195827'},
#      {'item': 'Five Star', 'count': '187645'},
#      {'item': 'Hennessy VS', 'count': '182571'},
#      {'item': 'Crown Royal Regal Apple', 'count': '180975'},
#      {'item': 'Seagrams 7 Crown Bl Whiskey', 'count': '180805'},
#      {'item': 'Jack Daniels Old #7 Black Lbl', 'count': '175576'},
#      {'item': 'Paramount White Rum', 'count': '170168'},
#      {'item': 'Southern Comfort', 'count': '164918'},
#      {'item': 'Smirnoff 80prf', 'count': '162007'},
#      {'item': 'Malibu Coconut Rum', 'count': '159199'}],
#     'not_null': '17300913',
#     'smallest': '100 Anos Anejo',
#     'count': '24396811',
#     'cardinality': '10653'},
#    'format': {'align': 'left'}},
#   {'id': 421004107,
#    'name': 'Pack',
#    'dataTypeName': 'number',
#    'description': 'The number of bottles in a case for the liquor ordered',
#    'fieldName': 'pack',
#    'position': 17,
#    'renderTypeName': 'number',
#    'tableColumnId': 22767861,
#    'width': 59,
#    'cachedContents': {'largest': '336',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': '12', 'count': '13881524'},
#      {'item': '6', 'count': '6788956'},
#      {'item': '24', 'count': '2210487'},
#      {'item': '48', 'count': '614123'},
#      {'item': '10', 'count': '480002'},
#      {'item': '1', 'count': '185447'},
#      {'item': '8', 'count': '70609'},
#      {'item': '5', 'count': '55260'},
#      {'item': '44', 'count': '40996'},
#      {'item': '4', 'count': '34266'},
#      {'item': '3', 'count': '26290'},
#      {'item': '15', 'count': '2306'},
#      {'item': '9', 'count': '1976'},
#      {'item': '60', 'count': '1250'},
#      {'item': '20', 'count': '1079'},
#      {'item': '30', 'count': '695'},
#      {'item': '2', 'count': '644'},
#      {'item': '16', 'count': '411'},
#      {'item': '18', 'count': '282'},
#      {'item': '288', 'count': '101'}],
#     'not_null': '17300913',
#     'smallest': '1',
#     'count': '24396811',
#     'cardinality': '28'},
#    'format': {'precisionStyle': 'standard',
#     'noCommas': 'true',
#     'align': 'right'}},
#   {'id': 421004108,
#    'name': 'Bottle Volume (ml)',
#    'dataTypeName': 'number',
#    'description': 'Volume of each liquor bottle ordered in milliliters.',
#    'fieldName': 'bottle_volume_ml',
#    'position': 18,
#    'renderTypeName': 'number',
#    'tableColumnId': 22767862,
#    'width': 117,
#    'cachedContents': {'largest': '378000',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': '750', 'count': '10954000'},
#      {'item': '1750', 'count': '4823230'},
#      {'item': '1000', 'count': '3063924'},
#      {'item': '375', 'count': '2495984'},
#      {'item': '200', 'count': '865409'},
#      {'item': '50', 'count': '808571'},
#      {'item': '500', 'count': '730575'},
#      {'item': '600', 'count': '221204'},
#      {'item': '100', 'count': '169086'},
#      {'item': '3000', 'count': '95623'},
#      {'item': '300', 'count': '94482'},
#      {'item': '800', 'count': '22460'},
#      {'item': '1200', 'count': '19916'},
#      {'item': '2400', 'count': '8204'},
#      {'item': '850', 'count': '3422'},
#      {'item': '1800', 'count': '2644'},
#      {'item': '400', 'count': '2223'},
#      {'item': '1850', 'count': '1896'},
#      {'item': '20', 'count': '1844'},
#      {'item': '900', 'count': '1521'}],
#     'not_null': '17300913',
#     'smallest': '0',
#     'count': '24396811',
#     'cardinality': '58'},
#    'format': {'precisionStyle': 'standard',
#     'noCommas': 'false',
#     'align': 'right'}},
#   {'id': 421004109,
#    'name': 'State Bottle Cost',
#    'dataTypeName': 'number',
#    'description': 'The amount that Alcoholic Beverages Division paid for each bottle of liquor ordered',
#    'fieldName': 'state_bottle_cost',
#    'position': 19,
#    'renderTypeName': 'number',
#    'tableColumnId': 22768160,
#    'width': 100,
#    'cachedContents': {'largest': '7680.00',
#     'non_null': '24396801',
#     'null': '10',
#     'top': [{'item': '8.25', 'count': '485339'},
#      {'item': '7.50', 'count': '430010'},
#      {'item': '10.00', 'count': '411791'},
#      {'item': '6.50', 'count': '405374'},
#      {'item': '5.00', 'count': '324107'},
#      {'item': '11.00', 'count': '257110'},
#      {'item': '8.00', 'count': '253051'},
#      {'item': '3.50', 'count': '249412'},
#      {'item': '7.00', 'count': '248485'},
#      {'item': '6.00', 'count': '243103'},
#      {'item': '10.45', 'count': '236530'},
#      {'item': '10.50', 'count': '234419'},
#      {'item': '9.00', 'count': '230543'},
#      {'item': '10.49', 'count': '224950'},
#      {'item': '7.17', 'count': '223290'},
#      {'item': '5.23', 'count': '220938'},
#      {'item': '15.00', 'count': '216731'},
#      {'item': '9.06', 'count': '207133'},
#      {'item': '13.00', 'count': '197356'},
#      {'item': '13.50', 'count': '193811'}],
#     'not_null': '17300903',
#     'smallest': '0.00',
#     'count': '24396811',
#     'cardinality': '3330'},
#    'format': {'precisionStyle': 'currency',
#     'humane': 'false',
#     'currencyStyle': 'USD',
#     'precision': '2',
#     'align': 'right'}},
#   {'id': 421004110,
#    'name': 'State Bottle Retail',
#    'dataTypeName': 'number',
#    'description': 'The amount the store paid for each bottle of liquor ordered',
#    'fieldName': 'state_bottle_retail',
#    'position': 20,
#    'renderTypeName': 'number',
#    'tableColumnId': 22768161,
#    'width': 115,
#    'cachedContents': {'largest': '11520.00',
#     'non_null': '24396801',
#     'null': '10',
#     'top': [{'item': '12.38', 'count': '432156'},
#      {'item': '11.25', 'count': '404679'},
#      {'item': '15.00', 'count': '383248'},
#      {'item': '9.75', 'count': '351848'},
#      {'item': '7.50', 'count': '313670'},
#      {'item': '12.00', 'count': '249101'},
#      {'item': '5.25', 'count': '244332'},
#      {'item': '16.50', 'count': '235183'},
#      {'item': '10.50', 'count': '234822'},
#      {'item': '15.74', 'count': '229841'},
#      {'item': '13.50', 'count': '229502'},
#      {'item': '10.76', 'count': '223061'},
#      {'item': '15.75', 'count': '215901'},
#      {'item': '9.00', 'count': '211974'},
#      {'item': '15.68', 'count': '206828'},
#      {'item': '13.59', 'count': '206654'},
#      {'item': '22.50', 'count': '196441'},
#      {'item': '20.25', 'count': '185890'},
#      {'item': '7.85', 'count': '185037'},
#      {'item': '8.25', 'count': '183093'}],
#     'not_null': '17300903',
#     'smallest': '0.00',
#     'count': '24396811',
#     'cardinality': '3798'},
#    'format': {'precisionStyle': 'currency',
#     'humane': 'false',
#     'currencyStyle': 'USD',
#     'precision': '2',
#     'align': 'right'}},
#   {'id': 421004111,
#    'name': 'Bottles Sold',
#    'dataTypeName': 'number',
#    'description': 'The number of bottles of liquor ordered by the store',
#    'fieldName': 'sale_bottles',
#    'position': 21,
#    'renderTypeName': 'number',
#    'tableColumnId': 22768162,
#    'width': 100,
#    'cachedContents': {'largest': '15000',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': '12', 'count': '6450688'},
#      {'item': '6', 'count': '4950407'},
#      {'item': '2', 'count': '3192679'},
#      {'item': '1', 'count': '2722889'},
#      {'item': '3', 'count': '2388454'},
#      {'item': '24', 'count': '1398938'},
#      {'item': '4', 'count': '1313804'},
#      {'item': '48', 'count': '380572'},
#      {'item': '5', 'count': '304967'},
#      {'item': '36', 'count': '198496'},
#      {'item': '10', 'count': '177841'},
#      {'item': '18', 'count': '167823'},
#      {'item': '8', 'count': '145337'},
#      {'item': '60', 'count': '115490'},
#      {'item': '30', 'count': '68515'},
#      {'item': '96', 'count': '51108'},
#      {'item': '72', 'count': '46307'},
#      {'item': '120', 'count': '40220'},
#      {'item': '7', 'count': '33644'},
#      {'item': '144', 'count': '22261'}],
#     'not_null': '17300913',
#     'smallest': '-156',
#     'count': '24396811',
#     'cardinality': '678'},
#    'format': {'precisionStyle': 'standard',
#     'noCommas': 'false',
#     'align': 'right'}},
#   {'id': 421004112,
#    'name': 'Sale (Dollars)',
#    'dataTypeName': 'number',
#    'description': 'Total cost of liquor order (number of bottles multiplied by the state bottle retail)',
#    'fieldName': 'sale_dollars',
#    'position': 22,
#    'renderTypeName': 'number',
#    'tableColumnId': 22768170,
#    'width': 100,
#    'cachedContents': {'largest': '279557.28',
#     'non_null': '24396801',
#     'null': '10',
#     'top': [{'item': '90.00', 'count': '264845'},
#      {'item': '135.00', 'count': '219019'},
#      {'item': '162.00', 'count': '178418'},
#      {'item': '148.56', 'count': '178400'},
#      {'item': '64.80', 'count': '171465'},
#      {'item': '180.00', 'count': '171121'},
#      {'item': '45.00', 'count': '160265'},
#      {'item': '126.00', 'count': '143770'},
#      {'item': '94.20', 'count': '131977'},
#      {'item': '72.00', 'count': '130118'},
#      {'item': '64.56', 'count': '129783'},
#      {'item': '117.00', 'count': '124271'},
#      {'item': '62.28', 'count': '121486'},
#      {'item': '99.00', 'count': '119506'},
#      {'item': '60.12', 'count': '119035'},
#      {'item': '94.08', 'count': '115872'},
#      {'item': '60.72', 'count': '111030'},
#      {'item': '22.50', 'count': '110722'},
#      {'item': '63.00', 'count': '110306'},
#      {'item': '30.00', 'count': '105563'}],
#     'not_null': '17300903',
#     'smallest': '-1348.80',
#     'count': '24396811',
#     'cardinality': '30991'},
#    'format': {'precisionStyle': 'currency',
#     'humane': 'false',
#     'currencyStyle': 'USD',
#     'precision': '2',
#     'align': 'right'}},
#   {'id': 421004113,
#    'name': 'Volume Sold (Liters)',
#    'dataTypeName': 'number',
#    'description': 'Total volume of liquor ordered in liters.  (i.e. (Bottle Volume (ml) x Bottles Sold)/1,000)',
#    'fieldName': 'sale_liters',
#    'position': 23,
#    'renderTypeName': 'number',
#    'tableColumnId': 33137109,
#    'width': 120,
#    'cachedContents': {'largest': '15000.00',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': '9.00', 'count': '4720243'},
#      {'item': '10.50', 'count': '3152331'},
#      {'item': '1.50', 'count': '2021687'},
#      {'item': '2.25', 'count': '1695288'},
#      {'item': '4.50', 'count': '1467393'},
#      {'item': '0.75', 'count': '1457824'},
#      {'item': '12.00', 'count': '1435904'},
#      {'item': '3.00', 'count': '1131679'},
#      {'item': '21.00', 'count': '484505'},
#      {'item': '1.00', 'count': '450877'},
#      {'item': '0.50', 'count': '391169'},
#      {'item': '2.00', 'count': '390830'},
#      {'item': '3.50', 'count': '346924'},
#      {'item': '18.00', 'count': '343415'},
#      {'item': '0.60', 'count': '299194'},
#      {'item': '1.12', 'count': '298582'},
#      {'item': '0.05', 'count': '281462'},
#      {'item': '6.00', 'count': '279854'},
#      {'item': '1.75', 'count': '256682'},
#      {'item': '24.00', 'count': '246095'}],
#     'not_null': '17300913',
#     'smallest': '-156.00',
#     'count': '24396811',
#     'cardinality': '1539'},
#    'format': {'precisionStyle': 'standard',
#     'noCommas': 'false',
#     'precision': '2',
#     'align': 'right'}},
#   {'id': 421004114,
#    'name': 'Volume Sold (Gallons)',
#    'dataTypeName': 'number',
#    'description': 'Total volume of liquor ordered in gallons. (i.e. (Bottle Volume (ml) x Bottles Sold)/3785.411784)',
#    'fieldName': 'sale_gallons',
#    'position': 24,
#    'renderTypeName': 'number',
#    'tableColumnId': 33137110,
#    'width': 128,
#    'cachedContents': {'largest': '3962.58',
#     'non_null': '24396811',
#     'null': '0',
#     'top': [{'item': '2.77', 'count': '3152331'},
#      {'item': '2.38', 'count': '2745687'},
#      {'item': '2.37', 'count': '1974556'},
#      {'item': '0.59', 'count': '1695288'},
#      {'item': '3.17', 'count': '1435904'},
#      {'item': '0.40', 'count': '1279070'},
#      {'item': '0.79', 'count': '1131679'},
#      {'item': '0.20', 'count': '889135'},
#      {'item': '1.18', 'count': '771600'},
#      {'item': '0.39', 'count': '742638'},
#      {'item': '1.19', 'count': '695793'},
#      {'item': '0.19', 'count': '568692'},
#      {'item': '0.26', 'count': '450805'},
#      {'item': '0.13', 'count': '391177'},
#      {'item': '0.92', 'count': '346924'},
#      {'item': '5.55', 'count': '287455'},
#      {'item': '0.01', 'count': '282012'},
#      {'item': '0.53', 'count': '268499'},
#      {'item': '0.46', 'count': '256682'},
#      {'item': '6.34', 'count': '246095'}],
#     'not_null': '17300913',
#     'smallest': '-41.21',
#     'count': '24396811',
#     'cardinality': '1836'},
#    'format': {'precisionStyle': 'standard',
#     'noCommas': 'false',
#     'precision': '2',
#     'align': 'right'}},
#   {'id': 421004115,
#    'name': 'Iowa ZIP Code Tabulation Areas',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_3r5t_5243',
#    'position': 29,
#    'renderTypeName': 'number',
#    'tableColumnId': 78271928,
#    'computationStrategy': {'source_columns': ['store_location'],
#     'type': 'georegion_match_on_point',
#     'parameters': {'region': '_3r5t-5243', 'primary_key': '_feature_id'}},
#    'format': {}},
#   {'id': 421004116,
#    'name': 'Iowa Watershed Sub-Basins (HUC 08)',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_wnea_7qqw',
#    'position': 30,
#    'renderTypeName': 'number',
#    'tableColumnId': 78271929,
#    'computationStrategy': {'source_columns': ['store_location'],
#     'type': 'georegion_match_on_point',
#     'parameters': {'region': '_wnea-7qqw', 'primary_key': '_feature_id'}},
#    'format': {}},
#   {'id': 421004117,
#    'name': 'Iowa Watersheds (HUC 10)',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_i9mz_6gmt',
#    'position': 31,
#    'renderTypeName': 'number',
#    'tableColumnId': 78271930,
#    'computationStrategy': {'source_columns': ['store_location'],
#     'type': 'georegion_match_on_point',
#     'parameters': {'region': '_i9mz-6gmt', 'primary_key': '_feature_id'}},
#    'format': {}},
#   {'id': 421004118,
#    'name': 'County Boundaries of Iowa',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_uhgg_e8y2',
#    'position': 32,
#    'renderTypeName': 'number',
#    'tableColumnId': 78271931,
#    'computationStrategy': {'source_columns': ['store_location'],
#     'type': 'georegion_match_on_point',
#     'parameters': {'region': '_uhgg-e8y2', 'primary_key': '_feature_id'}},
#    'format': {}},
#   {'id': 421004119,
#    'name': 'US Counties',
#    'dataTypeName': 'number',
#    'fieldName': ':@computed_region_e7ym_nrbf',
#    'position': 33,
#    'renderTypeName': 'number',
#    'tableColumnId': 78271932,
#    'computationStrategy': {'source_columns': ['store_location'],
#     'type': 'georegion_match_on_point',
#     'parameters': {'region': '_e7ym-nrbf', 'primary_key': '_feature_id'}},
#    'format': {}}],
#  'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#  'license': {'name': 'Creative Commons 1.0 Universal (Public Domain Dedication)',
#   'logoUrl': 'images/licenses/ccZero.png',
#   'termsLink': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode'},
#  'metadata': {'rdfSubject': '0',
#   'rdfClass': '',
#   'custom_fields': {'Data Management': {'Publishing Agency': 'Alcoholic Beverages Division (Commerce)',
#     'Updates': 'Open',
#     'Publishing Notes': 'This data is updated monthly.  Data updates are typically available on the first day of each month.'},
#    'Data Coverage': {'Start Date': '2012-01-01', 'Location': 'Iowa'}},
#   'rowIdentifier': 421004091,
#   'rowLabel': 'individual product purchase',
#   'availableDisplayTypes': ['table', 'fatrow', 'page'],
#   'renderTypeConfig': {'visible': {'table': True}}},
#  'owner': {'id': 'mabe-sef7',
#   'displayName': 'Alcoholic Beverages Division (Commerce)',
#   'profileImageUrlLarge': '/api/users/mabe-sef7/profile_images/LARGE',
#   'profileImageUrlMedium': '/api/users/mabe-sef7/profile_images/THUMB',
#   'profileImageUrlSmall': '/api/users/mabe-sef7/profile_images/TINY',
#   'screenName': 'Alcoholic Beverages Division (Commerce)',
#   'type': 'interactive',
#   'flags': ['acceptedEula']},
#  'query': {},
#  'rights': ['read'],
#  'tableAuthor': {'id': 'nj4v-jwef',
#   'displayName': 'Alcoholic Beverages Division (Commerce)',
#   'profileImageUrlLarge': '/api/users/nj4v-jwef/profile_images/LARGE',
#   'profileImageUrlMedium': '/api/users/nj4v-jwef/profile_images/THUMB',
#   'profileImageUrlSmall': '/api/users/nj4v-jwef/profile_images/TINY',
#   'screenName': 'Alcoholic Beverages Division (Commerce)',
#   'type': 'interactive'},
#  'tags': ['liquor sales', 'spirit sales', 'store sales', 'liquor licensees'],
#  'flags': ['default',
#   'federated',
#   'internalToPublicFederatedView',
#   'ownerMayBeContacted',
#   'restorable',
#   'restorePossibleForType']}

# %%
dataset_metadata = pd.DataFrame(metadata['columns'])[['name', 'dataTypeName', 'description', 'fieldName']]
dataset_metadata
# Out:
#                                   name   dataTypeName  \
# 0                  Invoice/Item Number           text
# 1                                 Date  calendar_date
# 2                         Store Number           text
# 3                           Store Name           text
# 4                              Address           text
# 5                                 City           text
# 6                             Zip Code           text
# 7                       Store Location          point
# 8                        County Number           text
# 9                               County           text
# 10                            Category           text
# 11                       Category Name           text
# 12                       Vendor Number           text
# 13                         Vendor Name           text
# 14                         Item Number           text
# 15                    Item Description           text
# 16                                Pack         number
# 17                  Bottle Volume (ml)         number
# 18                   State Bottle Cost         number
# 19                 State Bottle Retail         number
# 20                        Bottles Sold         number
# 21                      Sale (Dollars)         number
# 22                Volume Sold (Liters)         number
# 23               Volume Sold (Gallons)         number
# 24      Iowa ZIP Code Tabulation Areas         number
# 25  Iowa Watershed Sub-Basins (HUC 08)         number
# 26            Iowa Watersheds (HUC 10)         number
# 27           County Boundaries of Iowa         number
# 28                         US Counties         number
#
#                                           description  \
# 0   Concatenated invoice and line number associate...
# 1                                       Date of order
# 2   Unique number assigned to the store who ordere...
# 3               Name of store who ordered the liquor.
# 4            Address of store who ordered the liquor.
# 5   City where the store who ordered the liquor is...
# 6   Zip code where the store who ordered the liquo...
# 7   Location of store who ordered the liquor.  The...
# 8   Iowa county number for the county where store ...
# 9   County where the store who ordered the liquor ...
# 10   Category code associated with the liquor ordered
# 11                    Category of the liquor ordered.
# 12  The vendor number of the company for the brand...
# 13  The vendor name of the company for the brand o...
# 14  Item number for the individual liquor product ...
# 15  Description of the individual liquor product o...
# 16  The number of bottles in a case for the liquor...
# 17  Volume of each liquor bottle ordered in millil...
# 18  The amount that Alcoholic Beverages Division p...
# 19  The amount the store paid for each bottle of l...
# 20  The number of bottles of liquor ordered by the...
# 21  Total cost of liquor order (number of bottles ...
# 22  Total volume of liquor ordered in liters.  (i....
# 23  Total volume of liquor ordered in gallons. (i....
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#                       fieldName
# 0               invoice_line_no
# 1                          date
# 2                         store
# 3                          name
# 4                       address
# 5                          city
# 6                       zipcode
# 7                store_location
# 8                 county_number
# 9                        county
# 10                     category
# 11                category_name
# 12                    vendor_no
# 13                  vendor_name
# 14                       itemno
# 15                      im_desc
# 16                         pack
# 17             bottle_volume_ml
# 18            state_bottle_cost
# 19          state_bottle_retail
# 20                 sale_bottles
# 21                 sale_dollars
# 22                  sale_liters
# 23                 sale_gallons
# 24  :@computed_region_3r5t_5243
# 25  :@computed_region_wnea_7qqw
# 26  :@computed_region_i9mz_6gmt
# 27  :@computed_region_uhgg_e8y2
# 28  :@computed_region_e7ym_nrbf

# %% [markdown]
# # Location Data
#
# Gathering Lat and Long from `store_location`

# %%
coords = pd.DataFrame(results_df['store_location'].to_dict()).T
coords['coordinates'] = np.where(coords['coordinates'].isnull(), pd.Series([[]]*len(coords)), coords['coordinates']) # fill na with empty list
coords
# Out:
#        type                      coordinates
# 0     Point          [-92.917588, 43.378704]
# 1     Point  [-90.659692, 42.06922000000001]
# 2     Point          [-93.596754, 41.554101]
# 3     Point          [-93.621824, 41.705188]
# 4     Point          [-93.771698, 41.688332]
# ...     ...                              ...
# 1995  Point           [-93.613739, 41.60572]
# 1996    NaN                               []
# 1997  Point  [-93.60054000000001, 41.653137]
# 1998  Point           [-93.65129, 41.626668]
# 1999  Point          [-91.401062, 41.918663]
#
# [2000 rows x 2 columns]

# %%
pd.DataFrame(coords['coordinates'].to_list(), columns=['long', 'lat'])
# Out:
#            long        lat
# 0    -92.917588  43.378704
# 1    -90.659692  42.069220
# 2    -93.596754  41.554101
# 3    -93.621824  41.705188
# 4    -93.771698  41.688332
# ...         ...        ...
# 1995 -93.613739  41.605720
# 1996        NaN        NaN
# 1997 -93.600540  41.653137
# 1998 -93.651290  41.626668
# 1999 -91.401062  41.918663
#
# [2000 rows x 2 columns]

# %%
results_df = results_df.merge(pd.DataFrame(coords['coordinates'].to_list(), columns=['long', 'lat']), left_index=True, right_index=True)
results_df
# Out:
#      invoice_line_no                     date store  \
# 0       S32237200017  2016-05-10T00:00:00.000  4533
# 1       S32326100005  2016-05-16T00:00:00.000  3612
# 2       S32350600161  2016-05-16T00:00:00.000  2633
# 3       S32246800175  2016-05-10T00:00:00.000  2666
# 4       S32349300041  2016-05-17T00:00:00.000  4209
# ...              ...                      ...   ...
# 1995    S32344500098  2016-05-16T00:00:00.000  4829
# 1996    S32303000001  2016-05-18T00:00:00.000  2513
# 1997    S32294500007  2016-05-12T00:00:00.000  5169
# 1998    S32342800026  2016-05-16T00:00:00.000  2627
# 1999    S32324600024  2016-05-16T00:00:00.000  4856
#
#                                       name                         address  \
# 0     Casey's General Store #1985 / St. An                   110 N Hwy 218
# 1               B and C Liquor / Maquoketa                     509 E Platt
# 2             Hy-Vee #3 / BDI / Des Moines                 3221 SE 14th St
# 3                       Hy-Vee #2 / Ankeny                2510 SW State St
# 4                   Wal-Mart 5748 / Grimes                2150 East 1st St
# ...                                    ...                             ...
# 1995                        Central City 2               1501 Michigan Ave
# 1996      Hy-Vee Food Store #2 / Iowa City                  812  S 1st Ave
# 1997                          AV Superstop            5120, NE 14th Street
# 1998            Hy-Vee Wine and Spirits #1  3424 Martin Luther King Jr Pkw
# 1999              Brothers Market / Lisbon               930 Commercial St
#
#             city zipcode                                     store_location  \
# 0      St Ansgar   50472  {'type': 'Point', 'coordinates': [-92.917588, ...
# 1      Maquoketa   52060  {'type': 'Point', 'coordinates': [-90.659692, ...
# 2     Des Moines   50320  {'type': 'Point', 'coordinates': [-93.596754, ...
# 3         Ankeny   50023  {'type': 'Point', 'coordinates': [-93.621824, ...
# 4         Grimes   50111  {'type': 'Point', 'coordinates': [-93.771698, ...
# ...          ...     ...                                                ...
# 1995  Des Moines   50314  {'type': 'Point', 'coordinates': [-93.613739, ...
# 1996   Iowa City   52240                                                NaN
# 1997  Des Moines   50313  {'type': 'Point', 'coordinates': [-93.60054000...
# 1998  Des Moines   50310  {'type': 'Point', 'coordinates': [-93.65129, 4...
# 1999      Lisbon   52253  {'type': 'Point', 'coordinates': [-91.401062, ...
#
#      county_number    county  ... sale_dollars sale_liters sale_gallons  \
# 0               66  Mitchell  ...       377.76       18.00         4.76
# 1               49   Jackson  ...       162.00       10.50         2.77
# 2               77      Polk  ...       166.56       12.00         3.17
# 3               77      Polk  ...         9.00        0.75         0.20
# 4               77      Polk  ...        60.12        9.00         2.38
# ...            ...       ...  ...          ...         ...          ...
# 1995            77      Polk  ...        56.67        2.25         0.59
# 1996            52   Johnson  ...       194.70        7.50         1.98
# 1997            77      Polk  ...        34.44        0.80         0.21
# 1998            77      Polk  ...        51.75        1.50         0.40
# 1999            57      Linn  ...        51.96        3.00         0.79
#
#      :@computed_region_3r5t_5243 :@computed_region_wnea_7qqw  \
# 0                            461                          14
# 1                            153                           7
# 2                            483                          29
# 3                            831                          25
# 4                            654                          25
# ...                          ...                         ...
# 1995                         432                          25
# 1996                         NaN                         NaN
# 1997                         829                          25
# 1998                         684                          25
# 1999                         467                          19
#
#      :@computed_region_i9mz_6gmt :@computed_region_uhgg_e8y2  \
# 0                            171                          10
# 1                             80                          43
# 2                            356                          64
# 3                            316                          64
# 4                            315                          64
# ...                          ...                         ...
# 1995                         316                          64
# 1996                         NaN                         NaN
# 1997                         316                          64
# 1998                         316                          64
# 1999                         268                          45
#
#      :@computed_region_e7ym_nrbf       long        lat
# 0                            291 -92.917588  43.378704
# 1                           1790 -90.659692  42.069220
# 2                           1878 -93.596754  41.554101
# 3                           1878 -93.621824  41.705188
# 4                           1878 -93.771698  41.688332
# ...                          ...        ...        ...
# 1995                        1878 -93.613739  41.605720
# 1996                         NaN        NaN        NaN
# 1997                        1878 -93.600540  41.653137
# 1998                        1878 -93.651290  41.626668
# 1999                         287 -91.401062  41.918663
#
# [2000 rows x 31 columns]

# %%
h3_res = 8
def geo_to_h3(row):
    return h3.geo_to_h3(lat=row.lat,lng=row.long,resolution = h3_res)

# %%
results_df['hex_id'] = results_df.apply(geo_to_h3, axis=1)
results_df
# Out:
#      invoice_line_no                     date store  \
# 0       S32237200017  2016-05-10T00:00:00.000  4533
# 1       S32326100005  2016-05-16T00:00:00.000  3612
# 2       S32350600161  2016-05-16T00:00:00.000  2633
# 3       S32246800175  2016-05-10T00:00:00.000  2666
# 4       S32349300041  2016-05-17T00:00:00.000  4209
# ...              ...                      ...   ...
# 1995    S32344500098  2016-05-16T00:00:00.000  4829
# 1996    S32303000001  2016-05-18T00:00:00.000  2513
# 1997    S32294500007  2016-05-12T00:00:00.000  5169
# 1998    S32342800026  2016-05-16T00:00:00.000  2627
# 1999    S32324600024  2016-05-16T00:00:00.000  4856
#
#                                       name                         address  \
# 0     Casey's General Store #1985 / St. An                   110 N Hwy 218
# 1               B and C Liquor / Maquoketa                     509 E Platt
# 2             Hy-Vee #3 / BDI / Des Moines                 3221 SE 14th St
# 3                       Hy-Vee #2 / Ankeny                2510 SW State St
# 4                   Wal-Mart 5748 / Grimes                2150 East 1st St
# ...                                    ...                             ...
# 1995                        Central City 2               1501 Michigan Ave
# 1996      Hy-Vee Food Store #2 / Iowa City                  812  S 1st Ave
# 1997                          AV Superstop            5120, NE 14th Street
# 1998            Hy-Vee Wine and Spirits #1  3424 Martin Luther King Jr Pkw
# 1999              Brothers Market / Lisbon               930 Commercial St
#
#             city zipcode                                     store_location  \
# 0      St Ansgar   50472  {'type': 'Point', 'coordinates': [-92.917588, ...
# 1      Maquoketa   52060  {'type': 'Point', 'coordinates': [-90.659692, ...
# 2     Des Moines   50320  {'type': 'Point', 'coordinates': [-93.596754, ...
# 3         Ankeny   50023  {'type': 'Point', 'coordinates': [-93.621824, ...
# 4         Grimes   50111  {'type': 'Point', 'coordinates': [-93.771698, ...
# ...          ...     ...                                                ...
# 1995  Des Moines   50314  {'type': 'Point', 'coordinates': [-93.613739, ...
# 1996   Iowa City   52240                                                NaN
# 1997  Des Moines   50313  {'type': 'Point', 'coordinates': [-93.60054000...
# 1998  Des Moines   50310  {'type': 'Point', 'coordinates': [-93.65129, 4...
# 1999      Lisbon   52253  {'type': 'Point', 'coordinates': [-91.401062, ...
#
#      county_number    county  ... sale_liters sale_gallons  \
# 0               66  Mitchell  ...       18.00         4.76
# 1               49   Jackson  ...       10.50         2.77
# 2               77      Polk  ...       12.00         3.17
# 3               77      Polk  ...        0.75         0.20
# 4               77      Polk  ...        9.00         2.38
# ...            ...       ...  ...         ...          ...
# 1995            77      Polk  ...        2.25         0.59
# 1996            52   Johnson  ...        7.50         1.98
# 1997            77      Polk  ...        0.80         0.21
# 1998            77      Polk  ...        1.50         0.40
# 1999            57      Linn  ...        3.00         0.79
#
#      :@computed_region_3r5t_5243 :@computed_region_wnea_7qqw  \
# 0                            461                          14
# 1                            153                           7
# 2                            483                          29
# 3                            831                          25
# 4                            654                          25
# ...                          ...                         ...
# 1995                         432                          25
# 1996                         NaN                         NaN
# 1997                         829                          25
# 1998                         684                          25
# 1999                         467                          19
#
#      :@computed_region_i9mz_6gmt :@computed_region_uhgg_e8y2  \
# 0                            171                          10
# 1                             80                          43
# 2                            356                          64
# 3                            316                          64
# 4                            315                          64
# ...                          ...                         ...
# 1995                         316                          64
# 1996                         NaN                         NaN
# 1997                         316                          64
# 1998                         316                          64
# 1999                         268                          45
#
#      :@computed_region_e7ym_nrbf       long        lat           hex_id
# 0                            291 -92.917588  43.378704  882628a363fffff
# 1                           1790 -90.659692  42.069220  88267486d3fffff
# 2                           1878 -93.596754  41.554101  88260d846dfffff
# 3                           1878 -93.621824  41.705188  88260d9545fffff
# 4                           1878 -93.771698  41.688332  88260d8301fffff
# ...                          ...        ...        ...              ...
# 1995                        1878 -93.613739  41.605720  88260d8745fffff
# 1996                         NaN        NaN        NaN                0
# 1997                        1878 -93.600540  41.653137  88260d95edfffff
# 1998                        1878 -93.651290  41.626668  88260d8287fffff
# 1999                         287 -91.401062  41.918663  88267419d7fffff
#
# [2000 rows x 32 columns]

# %%
results_df['sale_bottles'] = results_df['sale_bottles'].astype(int)

# %%
results_df.dropna()[['sale_bottles', 'hex_id']].groupby('hex_id').sum().reset_index().to_csv('initial_hex.csv', index=False)

# %%
# Out:
#               hex_id sale_bottles
# 0    8c26010250441ff        12126
# 1    8c26010de4d45ff           10
# 2    8c2601156c5a9ff         6123
# 3    8c26015656863ff            3
# 4    8c260170cb53bff           12
# ..               ...          ...
# 601  8c275b7882e23ff          446
# 602  8c275b7891513ff         1262
# 603  8c275b78b7a1dff     12121212
# 604  8c275b78cae61ff           12
# 605  8c275b7ab2401ff          246
#
# [606 rows x 2 columns]

# %%
results_df.dtypes
# Out:
# invoice_line_no                 object
# date                            object
# store                           object
# name                            object
# address                         object
# city                            object
# zipcode                         object
# store_location                  object
# county_number                   object
# county                          object
# category                        object
# category_name                   object
# vendor_no                       object
# vendor_name                     object
# itemno                          object
# im_desc                         object
# pack                            object
# bottle_volume_ml                object
# state_bottle_cost               object
# state_bottle_retail             object
# sale_bottles                    object
# sale_dollars                    object
# sale_liters                     object
# sale_gallons                    object
# :@computed_region_3r5t_5243     object
# :@computed_region_wnea_7qqw     object
# :@computed_region_i9mz_6gmt     object
# :@computed_region_uhgg_e8y2     object
# :@computed_region_e7ym_nrbf     object
# long                           float64
# lat                            float64
# hex_id                          object
# dtype: object

# %%
results_df['date'] = pd.to_datetime(results_df['date'])

# %%
results_df['date'].min()
# Out:
# Timestamp('2016-05-10 00:00:00')

# %%
results_df['date'].max()
# Out:
# Timestamp('2016-07-20 00:00:00')

# %%
results_df.dtypes
# Out:
# invoice_line_no                 object
# date                            object
# store                           object
# name                            object
# address                         object
# city                            object
# zipcode                         object
# store_location                  object
# county_number                   object
# county                          object
# category                        object
# category_name                   object
# vendor_no                       object
# vendor_name                     object
# itemno                          object
# im_desc                         object
# pack                            object
# bottle_volume_ml                object
# state_bottle_cost               object
# state_bottle_retail             object
# sale_bottles                     int64
# sale_dollars                    object
# sale_liters                     object
# sale_gallons                    object
# :@computed_region_3r5t_5243     object
# :@computed_region_wnea_7qqw     object
# :@computed_region_i9mz_6gmt     object
# :@computed_region_uhgg_e8y2     object
# :@computed_region_e7ym_nrbf     object
# long                           float64
# lat                            float64
# hex_id                          object
# dtype: object

# %% [markdown]
# # Query Trials

# %%
client = Socrata("data.iowa.gov", app_token=TOKEN)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get(liquor_sales_data_id, limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df

# %%
import requests

# https://data.iowa.gov/resource/m3tr-qhgy.json?vendor_name=10th Mountain Whiskey %26 Spirit Company
# url = f"https://data.seattle.gov/resource/kzjm-xkqj.json?vendor_name=10th Mountain Whiskey %26 Spirit Company$$app_token={TOKEN}"
url = f"https://data.iowa.gov/resource/m3tr-qhgy.json?$$app_token={TOKEN}&$limit=20&$where=(vendor_name like '%10th Mountain%')"
r = requests.get(url=url).json()
r
# Out:
# [{'invoice_line_no': 'INV-07369100005',
#   'date': '2017-09-20T00:00:00.000',
#   'store': '3869',
#   'name': "Bootleggin' Barzini's Fin",
#   'address': '412  1st Ave',
#   'city': 'Coralville',
#   'zipcode': '52241',
#   'store_location': {'type': 'Point', 'coordinates': [-91.565517, 41.672672]},
#   'county_number': '52',
#   'county': 'JOHNSON',
#   'category': '1011700',
#   'category_name': 'Corn Whiskies',
#   'vendor_no': '522',
#   'vendor_name': '10th Mountain Whiskey & Spirit Company',
#   'itemno': '928012',
#   'im_desc': '10th Mountain Bourbon',
#   'pack': '6',
#   'bottle_volume_ml': '750',
#   'state_bottle_cost': '32.50',
#   'state_bottle_retail': '48.75',
#   'sale_bottles': '6',
#   'sale_dollars': '292.50',
#   'sale_liters': '4.50',
#   'sale_gallons': '1.19'}]

# %%
pd.DataFrame(r)
# Out:
#    invoice_line_no                     date store                       name  \
# 0  INV-07369100005  2017-09-20T00:00:00.000  3869  Bootleggin' Barzini's Fin
#
#         address        city zipcode  \
# 0  412  1st Ave  Coralville   52241
#
#                                       store_location county_number   county  \
# 0  {'type': 'Point', 'coordinates': [-91.565517, ...            52  JOHNSON
#
#    ...  itemno                im_desc pack bottle_volume_ml state_bottle_cost  \
# 0  ...  928012  10th Mountain Bourbon    6              750             32.50
#
#   state_bottle_retail sale_bottles sale_dollars sale_liters sale_gallons
# 0               48.75            6       292.50        4.50         1.19
#
# [1 rows x 24 columns]

# %% [markdown]
# # Setting up Functions

# %%
def clean_dataframe(df, h3_resolution=8):
    coords_df = pd.DataFrame(df['store_location'].to_dict()).T
    coords_df['coordinates'] = np.where(coords_df['coordinates'].isnull(), pd.Series([[]]*len(coords_df)), coords_df['coordinates']) # fill na with empty list
    df = df.merge(pd.DataFrame(coords_df['coordinates'].to_list(), columns=['long', 'lat']), left_index=True, right_index=True)


    def lat_long_to_h3(row):
        return h3.geo_to_h3(lat=row.lat,lng=row.long,resolution = h3_resolution)

    df['hex_id'] = df.apply(lat_long_to_h3, axis=1)

    return df

# %%
def get_data_chunk(resource_id, n_records=5000):

    BASE_URL = f"https://data.iowa.gov/resource/{resource_id}.json?$$app_token={TOKEN}"
    query_url=f"&$limit={n_records}"
    url = f"{BASE_URL}{query_url}"
    response_json = requests.get(url=url).json()
    df = pd.DataFrame(response_json)
    df = clean_dataframe(df)
    return df

# %%
test_query = get_data_chunk(resource_id=liquor_sales_data_id)
test_query
# Out:
#       invoice_line_no                     date store  \
# 0     INV-26823500051  2020-04-24T00:00:00.000  5327
# 1     INV-26826500068  2020-04-24T00:00:00.000  2550
# 2     INV-26852900040  2020-04-27T00:00:00.000  2649
# 3     INV-26854500004  2020-04-27T00:00:00.000  4548
# 4     INV-26837400039  2020-04-27T00:00:00.000  4373
# ...               ...                      ...   ...
# 4995  INV-26843300061  2020-04-27T00:00:00.000  4310
# 4996  INV-26828900027  2020-04-24T00:00:00.000  3818
# 4997  INV-26814300047  2020-04-24T00:00:00.000  5466
# 4998  INV-26794900029  2020-04-24T00:00:00.000  2672
# 4999  INV-26797700003  2020-04-24T00:00:00.000  5477
#
#                                          name                  address  \
# 0                                  Mega Saver          3540 W Broadway
# 1                 Hy-Vee Food Store / Osceola          510 West Mclane
# 2                         Hy-Vee #3 / Dubuque            400 Locust St
# 3        Casey's General Store #2594 / Walker             401 Grant St
# 4              Kum & Go #74 / West Des Moines  141 S Jordan Creek Pkwy
# ...                                       ...                      ...
# 4995           Fareway Stores #502 / Cherokee        205 West Bluff St
# 4996                      Round Window Liquor        703 W Pleasant St
# 4997               Southside Tobacco & Liquor        2424 SW 9th St #1
# 4998                       Hy-Vee / Winterset            923 N  1st St
# 4999  Casey's General Store #3293 / Marquette               103 1st St
#
#                  city zipcode  \
# 0      Council Bluffs   51501
# 1             Osceola   50213
# 2             Dubuque   52001
# 3              Walker   52352
# 4     West Des Moines   50266
# ...               ...     ...
# 4995         Cherokee   51012
# 4996        Knoxville   50138
# 4997       Des Moines   50315
# 4998        Winterset   50273
# 4999        Marquette   52158
#
#                                          store_location county_number  \
# 0     {'type': 'Point', 'coordinates': [-95.903763, ...            78
# 1     {'type': 'Point', 'coordinates': [-93.77321, 4...            20
# 2     {'type': 'Point', 'coordinates': [-90.666497, ...            31
# 3     {'type': 'Point', 'coordinates': [-91.781945, ...            57
# 4     {'type': 'Point', 'coordinates': [-93.809458, ...            77
# ...                                                 ...           ...
# 4995  {'type': 'Point', 'coordinates': [-95.551866, ...            18
# 4996  {'type': 'Point', 'coordinates': [-93.10564100...            63
# 4997  {'type': 'Point', 'coordinates': [-93.624729, ...            77
# 4998  {'type': 'Point', 'coordinates': [-94.013482, ...            61
# 4999  {'type': 'Point', 'coordinates': [-91.766633, ...            22
#
#           county  ... sale_liters sale_gallons :@computed_region_3r5t_5243  \
# 0     POTTAWATTA  ...        4.80         1.26                         219
# 1         CLARKE  ...        0.75         0.19                         133
# 2        DUBUQUE  ...        9.00         2.37                         768
# 3           LINN  ...        9.00         2.37                         381
# 4           POLK  ...        4.50         1.18                         881
# ...          ...  ...         ...          ...                         ...
# 4995    CHEROKEE  ...        3.00         0.79                         286
# 4996      MARION  ...        0.75         0.19                         916
# 4997        POLK  ...        3.00         0.79                         832
# 4998     MADISON  ...        9.00         2.37                         207
# 4999     CLAYTON  ...       36.00         9.51                         665
#
#      :@computed_region_wnea_7qqw :@computed_region_i9mz_6gmt  \
# 0                             40                         437
# 1                             29                         354
# 2                             55                          60
# 3                             18                         264
# 4                             27                         333
# ...                          ...                         ...
# 4995                          37                         429
# 4996                          29                         355
# 4997                          27                         333
# 4998                          29                         345
# 4999                           3                          36
#
#      :@computed_region_uhgg_e8y2 :@computed_region_e7ym_nrbf       long  \
# 0                             69                        1879 -95.903763
# 1                             86                         182 -93.773210
# 2                             31                        1780 -90.666497
# 3                             45                         287 -91.781945
# 4                             62                        1746 -93.809458
# ...                          ...                         ...        ...
# 4995                          23                         181 -95.551866
# 4996                          77                        1830 -93.105641
# 4997                          64                        1878 -93.624729
# 4998                          75                         289 -94.013482
# 4999                           7                        1890 -91.766633
#
#             lat           hex_id
# 0     41.261907  882608c935fffff
# 1     41.030569  88260d3a95fffff
# 2     42.497219  88275a211bfffff
# 3     42.283922  8826293685fffff
# 4     41.567246  88260d8a93fffff
# ...         ...              ...
# 4995  42.755080  882601b519fffff
# 4996  41.320746  8826767985fffff
# 4997  41.563730  88260d8735fffff
# 4998  41.342665  88260d030bfffff
# 4999  43.148082  88262d2c4dfffff
#
# [5000 rows x 32 columns]

# %% [markdown]
# # Testing Date Ranges

# %%
url = f"https://data.iowa.gov/resource/m3tr-qhgy.json?$$app_token={TOKEN}&$limit=20&$where=(date_extract_y(date) between 2022 and 2022)"
r = requests.get(url=url).json()
pd.DataFrame(r)
# Out:
#     invoice_line_no                     date store  \
# 0   INV-44364800004  2022-02-02T00:00:00.000  6248
# 1   INV-44345100002  2022-02-01T00:00:00.000  5933
# 2   INV-44341800004  2022-02-01T00:00:00.000  4153
# 3   INV-44359600062  2022-02-02T00:00:00.000  2619
# 4   INV-44310400024  2022-02-01T00:00:00.000  2544
# 5   INV-44362800017  2022-02-02T00:00:00.000  5003
# 6   INV-44353000121  2022-02-02T00:00:00.000  2502
# 7   INV-44327800010  2022-02-01T00:00:00.000  5609
# 8   INV-44298400012  2022-02-01T00:00:00.000  3563
# 9   INV-44306400026  2022-02-01T00:00:00.000  4253
# 10  INV-44306800027  2022-02-01T00:00:00.000  3943
# 11  INV-44326000023  2022-02-01T00:00:00.000  4148
# 12  INV-44329900016  2022-02-01T00:00:00.000  5882
# 13  INV-44376400026  2022-02-02T00:00:00.000  2565
# 14  INV-44364100018  2022-02-02T00:00:00.000  2647
# 15  INV-44359700012  2022-02-02T00:00:00.000  3899
# 16  INV-44331900089  2022-02-01T00:00:00.000  5423
# 17  INV-44297800010  2022-02-01T00:00:00.000  3918
# 18  INV-44363600004  2022-02-02T00:00:00.000  5916
# 19  INV-44311600038  2022-02-01T00:00:00.000  5645
#
#                                           name  \
# 0                    Quick Stop / Cedar Rapids
# 1                      Ali's Corner / Waterloo
# 2              Fareway Stores #067 / Evansdale
# 3                Hy-Vee Wine and Spirits / WDM
# 4             Hy-Vee Food Store / Marshalltown
# 5                               Famous Liquors
# 6             Hy-Vee Wine and Spirits / Ankeny
# 7        Casey's General Store #2682 / Oelwein
# 8                    Wal-Mart 0559 / Muscatine
# 9              Fareway Stores #683 / Winterset
# 10                           Good and Quick Co
# 11          Fareway Stores #479 / Independence
# 12               Hometown Foods / State Center
# 13           Hy-Vee Food Store #1636 / Spencer
# 14                    Hy-Vee #7 / Cedar Rapids
# 15                         Wal-Mart 3762 / WDM
# 16                         Stammer Liquor Corp
# 17  Smokin' Joe's #1 Tobacco and Liquor Outlet
# 18                      Another Round / DeWitt
# 19                      Phillips 66 / Grinnell
#
#                             address             city zipcode  \
# 0   380 Blairs Ferry Road Northeast     Cedar Rapids   52402
# 1                     1117 E 4th St         Waterloo   50703
# 2                    215 S Evans Rd        Evansdale   50707
# 3                     1725  74th St  West Des Moines   50266
# 4                  802 South Center     Marshalltown   50158
# 5                  2604 W Locust St        Davenport   52804
# 6             410 North Ankeny Blvd           Ankeny   50021
# 7                    105 1st Ave SE          Oelwein   50662
# 8                 3003 North Hwy 61        Muscatine   52761
# 9                      719 W Hwy 92        Winterset   50273
# 10                   519 Lincolnway           Nevada   50201
# 11                  1400 3rd Ave SE     Independence   50644
# 12                    120 E Main St     State Center   50247
# 13                  819 N Grand Ave          Spencer   51301
# 14                 5050 Edgewood Rd     Cedar Rapids   52411
# 15               6365 Stagecoach Dr  West Des Moines   50266
# 16                      615 2nd Ave          Sheldon   51201
# 17               3120 Rockingham Rd        Davenport   52802
# 18                    622 S 6th Ave           DeWitt   52742
# 19                     1031 West St         Grinnell   50112
#
#                                        store_location county_number  \
# 0   {'type': 'Point', 'coordinates': [-91.638037, ...            57
# 1   {'type': 'Point', 'coordinates': [-92.332771, ...            48
# 2   {'type': 'Point', 'coordinates': [-92.287834, ...             7
# 3   {'type': 'Point', 'coordinates': [-93.808855, ...            77
# 4   {'type': 'Point', 'coordinates': [-92.91273, 4...            64
# 5   {'type': 'Point', 'coordinates': [-90.615543, ...            82
# 6                                                 NaN            77
# 7   {'type': 'Point', 'coordinates': [-91.911999, ...            33
# 8   {'type': 'Point', 'coordinates': [-91.025184, ...            70
# 9   {'type': 'Point', 'coordinates': [-94.022239, ...            61
# 10  {'type': 'Point', 'coordinates': [-93.453317, ...            85
# 11  {'type': 'Point', 'coordinates': [-91.890284, ...            10
# 12  {'type': 'Point', 'coordinates': [-94.363119, ...            64
# 13  {'type': 'Point', 'coordinates': [-95.14506, 4...            21
# 14  {'type': 'Point', 'coordinates': [-91.701581, ...            57
# 15  {'type': 'Point', 'coordinates': [-93.795445, ...            77
# 16  {'type': 'Point', 'coordinates': [-95.854899, ...            71
# 17  {'type': 'Point', 'coordinates': [-90.621612, ...            82
# 18  {'type': 'Point', 'coordinates': [-90.539056, ...            23
# 19  {'type': 'Point', 'coordinates': [-92.727379, ...            79
#
#         county  ... itemno                        im_desc pack  \
# 0         LINN  ...  18196  Ezra Brooks Sour Mash Bourbon   12
# 1         IOWA  ...  49185         Remy Martin VSOP Flask   12
# 2   BLACK HAWK  ...  11296                    Crown Royal   12
# 3         POLK  ...  27171        Minor Case Straight Rye    6
# 4     MARSHALL  ...  45275        Paramount White Rum PET   12
# 5        SCOTT  ...  36668                   Korski Vodka    6
# 6         POLK  ...  87280               Casamigos Blanco    6
# 7      FAYETTE  ...  11774                   Black Velvet   24
# 8    MUSCATINE  ...  25608               Seagrams 7 Crown    6
# 9      MADISON  ...  15626                        Jameson   12
# 10       STORY  ...  48105                    Hennessy VS   12
# 11    BUCHANAN  ...  77847               Smirnoff Vanilla   12
# 12    MARSHALL  ...  45277            Paramount White Rum   12
# 13        CLAY  ...  19066                       Jim Beam   12
# 14        LINN  ...  19112            Jim Beam Devils Cut   12
# 15        POLK  ...  52316          Christian Bros Brandy   12
# 16      OBRIEN  ...  88294                  Patron Silver   12
# 17       SCOTT  ...  64864      Fireball Cinnamon Whiskey   24
# 18     CLINTON  ...  76488             Paramount Amaretto    6
# 19   POWESHIEK  ...  37336                       UV Vodka   12
#
#    bottle_volume_ml state_bottle_cost state_bottle_retail sale_bottles  \
# 0               750              8.00               12.00            2
# 1               375             12.52               18.78           12
# 2               750             16.59               24.89           12
# 3               750             20.00               30.00            6
# 4               750              4.00                6.00           12
# 5              1750              7.25               10.88            6
# 6               750             26.84               40.26            3
# 7               375              3.07                4.61           24
# 8              1750             12.96               19.44            6
# 9               750             16.99               25.49           12
# 10              375             12.49               18.74            6
# 11              750              8.25               12.38            3
# 12             1000              4.42                6.63            2
# 13              750             11.00               16.50            2
# 14              750             14.00               21.00            3
# 15              750              6.00                9.00           12
# 16              375             15.00               22.50            1
# 17              375              5.33                8.00           24
# 18             1750              8.25               12.38            6
# 19              750              7.00               10.50            3
#
#    sale_dollars sale_liters sale_gallons
# 0         24.00        1.50         0.39
# 1        225.36        4.50         1.18
# 2        298.68        9.00         2.37
# 3        180.00        4.50         1.18
# 4         72.00        9.00         2.37
# 5         65.28       10.50         2.77
# 6        120.78        2.25         0.59
# 7        110.64        9.00         2.37
# 8        116.64       10.50         2.77
# 9        305.88        9.00         2.37
# 10       112.44        2.25         0.59
# 11        37.14        2.25         0.59
# 12        13.26        2.00         0.52
# 13        33.00        1.50         0.39
# 14        63.00        2.25         0.59
# 15       108.00        9.00         2.37
# 16        22.50        0.37         0.09
# 17       192.00        9.00         2.37
# 18        74.28       10.50         2.77
# 19        31.50        2.25         0.59
#
# [20 rows x 24 columns]

# %%
url= f"https://data.iowa.gov/resource/m3tr-qhgy.json?$$app_token={TOKEN}&$limit=none&$where=(date between '2022-01-01' and '2022-01-31')"
r = requests.get(url=url).json()
pd.DataFrame(r)
# Out:
#                               code  error  \
# position  query.compiler.malformed   True
# query     query.compiler.malformed   True
#
#                                                     message  \
# position  Could not parse SoQL query "select * where (da...
# query     Could not parse SoQL query "select * where (da...
#
#                                                        data
# position                                                 {}
# query     select * where (date between '2022-01-01' and ...

# %%
client = Socrata("data.iowa.gov", app_token=TOKEN)
results = client.get_all("m3tr-qhgy", where="(date between '2022-01-01' and '2022-01-31')")
socrata_df = pd.DataFrame.from_records(results)
socrata_df
# Out:
#         invoice_line_no                     date store  \
# 0       INV-43468500052  2022-01-02T00:00:00.000  2190
# 1       INV-43468400001  2022-01-02T00:00:00.000  2536
# 2       INV-43468400006  2022-01-02T00:00:00.000  2536
# 3       INV-43468400011  2022-01-02T00:00:00.000  2536
# 4       INV-43468500039  2022-01-02T00:00:00.000  2190
# ...                 ...                      ...   ...
# 182590  INV-44266300017  2022-01-31T00:00:00.000  6018
# 182591  INV-44260900001  2022-01-31T00:00:00.000  5873
# 182592  INV-44284600001  2022-01-31T00:00:00.000  6178
# 182593  INV-44264900016  2022-01-31T00:00:00.000  5736
# 182594  INV-44263000006  2022-01-31T00:00:00.000  6059
#
#                                             name              address  \
# 0                      Central City Liquor, Inc.         1460 2ND AVE
# 1                         HY-VEE / PLEASANT HILL     4815 Maple Drive
# 2                         HY-VEE / PLEASANT HILL     4815 Maple Drive
# 3                         HY-VEE / PLEASANT HILL     4815 Maple Drive
# 4                      Central City Liquor, Inc.         1460 2ND AVE
# ...                                          ...                  ...
# 182590             Casey's General Store - #2532   1807 Edgington Ave
# 182591                            West D Liquors    5014 EP True Pkwy
# 182592           Hy-Vee Dollar Fresh / Maquoketa       102 W Carlisle
# 182593                          218 Fuel Express     68 Monroe Street
# 182594  Casey's General Store #1793 / Iowa Falls  1801 Washington Ave
#
#                    city zipcode  \
# 0            Des Moines   50314
# 1         Pleasant Hill   50317
# 2         Pleasant Hill   50317
# 3         Pleasant Hill   50317
# 4            Des Moines   50314
# ...                 ...     ...
# 182590           Eldora   50627
# 182591  West Des Moines   50265
# 182592        Maquoketa   52060
# 182593            Floyd   50435
# 182594       Iowa Falls   50126
#
#                                            store_location county_number  \
# 0       {'type': 'Point', 'coordinates': [-93.619788, ...            77
# 1       {'type': 'Point', 'coordinates': [-93.519491, ...            77
# 2       {'type': 'Point', 'coordinates': [-93.519491, ...            77
# 3       {'type': 'Point', 'coordinates': [-93.519491, ...            77
# 4       {'type': 'Point', 'coordinates': [-93.619788, ...            77
# ...                                                   ...           ...
# 182590  {'type': 'Point', 'coordinates': [-93.10607700...            42
# 182591  {'type': 'Point', 'coordinates': [-93.772906, ...            77
# 182592                                                NaN            49
# 182593  {'type': 'Point', 'coordinates': [-92.73738, 4...            34
# 182594  {'type': 'Point', 'coordinates': [-93.279976, ...            42
#
#          county  ... itemno                           im_desc pack  \
# 0          POLK  ...   5362                 John Barr Reserve   12
# 1          Polk  ...  34001  Absolut Swedish Vodka 80prf Mini   10
# 2          Polk  ...  39825             Western Son Blueberry   12
# 3          Polk  ...  25616        Seagrams 7 Crown PET Flask   12
# 4          POLK  ...  88533                 Mi Campo Reposado   12
# ...         ...  ...    ...                               ...  ...
# 182590   HARDIN  ...  48105                       Hennessy VS   12
# 182591     POLK  ...  48099                       Hennessy VS   24
# 182592  JACKSON  ...  17916                      Elijah Craig   12
# 182593    FLOYD  ...  48105                       Hennessy VS   12
# 182594   HARDIN  ...  27780               Jim Beam Apple Mini   12
#
#        bottle_volume_ml state_bottle_cost state_bottle_retail sale_bottles  \
# 0                   750             11.67               17.51            3
# 1                    50              7.92               11.88           10
# 2                   750              9.01               13.52           12
# 3                   750              7.50               11.25           12
# 4                   750             12.40               18.60            2
# ...                 ...               ...                 ...          ...
# 182590              375             12.49               18.74            3
# 182591              200              7.49               11.24           24
# 182592              750             16.00               24.00           12
# 182593              375             12.49               18.74            6
# 182594               50              7.00               10.50            1
#
#        sale_dollars sale_liters sale_gallons
# 0             52.53        2.25         0.59
# 1            118.80        0.50         0.13
# 2            162.24        9.00         2.37
# 3            135.00        9.00         2.37
# 4             37.20        1.50         0.39
# ...             ...         ...          ...
# 182590        56.22        1.12         0.29
# 182591       269.76        4.80         1.26
# 182592       288.00        9.00         2.37
# 182593       112.44        2.25         0.59
# 182594        10.50        0.05         0.01
#
# [182595 rows x 24 columns]

# %%
socrata_df['date'] = pd.to_datetime(socrata_df['date'])
socrata_df['date'].min()
# Out:
# Timestamp('2022-01-02 00:00:00')

# %%
socrata_df['date'].max()
# Out:
# Timestamp('2022-01-31 00:00:00')

# %%
182595 * 12
# Out:
# 2191140

# %%
client = Socrata("data.iowa.gov", app_token=TOKEN, timeout=60)
results = client.get_all("m3tr-qhgy", where="date_extract_y(date) between 2022 and 2022")
socrata_df_22 = pd.DataFrame.from_records(results)
socrata_df_22
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [171], in <cell line: 3>()
#       1 client = Socrata("data.iowa.gov", app_token=TOKEN, timeout=60)
#       2 results = client.get_all("m3tr-qhgy", where="date_extract_y(date) between 2022 and 2022")
# ----> 3 socrata_df_22 = pd.DataFrame.from_records(results)
#       4 socrata_df_22
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/pandas/core/frame.py:2192, in DataFrame.from_records(cls, data, index, exclude, columns, coerce_float, nrows)
#    2189 values = [first_row]
#    2191 if nrows is None:
# -> 2192     values += data
#    2193 else:
#    2194     values.extend(itertools.islice(data, nrows - 1))
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/sodapy/socrata.py:429, in Socrata.get_all(self, *args, **kwargs)
#     426 limit = params.get("limit", self.DEFAULT_LIMIT)
#     428 while True:
# --> 429     response = self.get(*args, **params)
#     430     for item in response:
#     431         yield item
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/sodapy/socrata.py:412, in Socrata.get(self, dataset_identifier, content_type, **kwargs)
#     409 params.update(kwargs)
#     410 params = utils.clear_empty_values(params)
# --> 412 response = self._perform_request(
#     413     "get", resource, headers=headers, params=params
#     414 )
#     415 return response
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/sodapy/socrata.py:551, in Socrata._perform_request(self, request_type, resource, **kwargs)
#     548 # set a timeout, just to be safe
#     549 kwargs["timeout"] = self.timeout
# --> 551 response = getattr(self.session, request_type)(uri, **kwargs)
#     553 # handle errors
#     554 if response.status_code not in (200, 202):
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/iowa/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/envs/iowa/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/envs/iowa/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/iowa/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/iowa/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/anaconda3/envs/iowa/lib/python3.10/ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/iowa/lib/python3.10/ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:
